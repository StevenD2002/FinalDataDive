# %% [markdown]
# ### DATA DIVE 2 Electric Boogaloo

# %%
# hell yeah

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score

# %matplotlib inline
#plt.style.use('seaborn-white')
sns.set_style('whitegrid')


#Widens the code landscape 

pd.set_option('display.max_columns',500)

import warnings
warnings.filterwarnings("ignore")

# %%
df_Hi = pd.read_csv('College_Admission_data.csv')
df_Hi.info()
df_Hi.head()
df_Hi.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Columns: 108 entries, Name to Endowment assets (year end) per FTE enrollment (FASB)
# dtypes: float64(97), object(11)
# memory usage: 1.3+ MB
#        Applicants total  Admissions total  Enrolled total  \
# count       1377.000000       1377.000000     1377.000000
# mean        6391.193174       3554.880174     1043.046478
# std         8787.469171       4309.457606     1285.165519
# min            0.000000          0.000000        0.000000
# 25%         1488.000000        950.000000      287.000000
# 50%         3350.000000       2056.000000      538.000000
# 75%         7016.000000       4203.000000     1246.000000
# max        72676.000000      35815.000000    10241.000000
#
#        Percent of freshmen submitting SAT scores  \
# count                                1257.000000
# mean                                   53.927605
# std                                    34.385164
# ...

# %%
msno.bar(df_Hi)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/stevendew/MTSU/School Projects/Modeling/FinalDataDive/DATADIVE2.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/stevendew/MTSU/School%20Projects/Modeling/FinalDataDive/DATADIVE2.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> msno.bar(df_Hi)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow/lib/python3.9/site-packages/missingno/missingno.py:266, in bar(df, figsize, fontsize, labels, log, color, inline, filter, n, p, sort, ax)
#     264 ax3.set_xticks(ax1.get_xticks())
#     265 ax3.set_xlim(ax1.get_xlim())
# --> 266 ax3.set_xticklabels(nullity_counts.values, fontsize=fontsize, rotation=45, ha='left')
#     267 ax3.grid(False)
#     269 for ax in axes:
#
# ...

# %%
CaCCi.isna()
df_Ca['Applicants total'].fillna(int(df_Ca['Applicants total'].mean()), inplace=True)
df_Ca['Admissions total'].fillna(int(df_Ca['Admissions total'].mean()), inplace=True)
df_Ca['Enrolled total'].fillna(int(df_Ca['Enrolled total'].mean()), inplace=True)
df_Ca['Percent of freshmen submitting SAT scores'].fillna(int(df_Ca['Percent of freshmen submitting SAT scores'].mean()), inplace=True)
df_Ca['Percent of freshmen submitting ACT scores'].fillna(int(df_Ca['Percent of freshmen submitting ACT scores'].mean()), inplace=True)
df_Ca['SAT Critical Reading 25th percentile score'].fillna(int(df_Ca['SAT Critical Reading 25th percentile score'].mean()), inplace=True)
df_Ca['SAT Critical Reading 75th percentile score'].fillna(int(df_Ca['SAT Critical Reading 75th percentile score'].mean()), inplace=True)
df_Ca['SAT Math 25th percentile score'].fillna(int(df_Ca['SAT Math 25th percentile score'].mean()), inplace=True)
df_Ca['SAT Math 75th percentile score'].fillna(int(df_Ca['SAT Math 75th percentile score'].mean()), inplace=True)
df_Ca['SAT Writing 25th percentile score'].fillna(int(df_Ca['SAT Writing 25th percentile score'].mean()), inplace=True)
df_Ca['SAT Writing 75th percentile score'].fillna(int(df_Ca['SAT Writing 75th percentile score'].mean()), inplace=True)
df_Ca['ACT Composite 25th percentile score'].fillna(int(df_Ca['ACT Composite 25th percentile score'].mean()), inplace=True)
df_Ca['ACT Composite 75th percentile score'].fillna(int(df_Ca['ACT Composite 75th percentile score'].mean()), inplace=True)
df_Ca['Estimated enrollment, total'].fillna(int(df_Ca['Estimated enrollment, total'].mean()), inplace=True)
df_Ca['Estimated enrollment, full time'].fillna(int(df_Ca['Estimated enrollment, full time'].mean()), inplace=True)
df_Ca['Estimated enrollment, part time'].fillna(int(df_Ca['Estimated enrollment, part time'].mean()), inplace=True)
df_Ca['Estimated undergraduate enrollment, total'].fillna(int(df_Ca['Estimated undergraduate enrollment, total'].mean()), inplace=True)
df_Ca['Estimated undergraduate enrollment, full time'].fillna(int(df_Ca['Estimated undergraduate enrollment, full time'].mean()), inplace=True)
df_Ca['Estimated undergraduate enrollment, part time'].fillna(int(df_Ca['Estimated undergraduate enrollment, part time'].mean()), inplace=True)
df_Ca['Estimated freshman undergraduate enrollment, total'].fillna(int(df_Ca['Estimated freshman undergraduate enrollment, total'].mean()), inplace=True)
df_Ca['Estimated freshman enrollment, full time'].fillna(int(df_Ca['Estimated freshman enrollment, full time'].mean()), inplace=True)
df_Ca['Estimated freshman enrollment, part time'].fillna(int(df_Ca['Estimated freshman enrollment, part time'].mean()), inplace=True)
df_Ca['Estimated graduate enrollment, total'].fillna(int(df_Ca['Estimated graduate enrollment, total'].mean()), inplace=True)
df_Ca['Estimated graduate enrollment, full time'].fillna(int(df_Ca['Estimated graduate enrollment, full time'].mean()), inplace=True)
df_Ca['Estimated graduate enrollment, part time'].fillna(int(df_Ca['Estimated graduate enrollment, part time'].mean()), inplace=True)
df_Ca['''Number of students receiving an Associate's degree'''].fillna(int(df_Ca['''Number of students receiving an Associate's degree'''].mean()), inplace=True)
df_Ca['Percent admitted - total'].fillna(int(df_Ca['Percent admitted - total'].mean()), inplace=True)
df_Ca['Admissions yield - total'].fillna(int(df_Ca['Admissions yield - total'].mean()), inplace=True)
df_Ca['Tuition and fees, 2010-11'].fillna(int(df_Ca['Tuition and fees, 2010-11'].mean()), inplace=True)
df_Ca['Tuition and fees, 2011-12'].fillna(int(df_Ca['Tuition and fees, 2011-12'].mean()), inplace=True)
df_Ca['Tuition and fees, 2012-13'].fillna(int(df_Ca['Tuition and fees, 2012-13'].mean()), inplace=True)
df_Ca['Tuition and fees, 2013-14'].fillna(int(df_Ca['Tuition and fees, 2013-14'].mean()), inplace=True)
df_Ca['Total price for in-state students living on campus 2013-14'].fillna(int(df_Ca['Total price for in-state students living on campus 2013-14'].mean()), inplace=True)
df_Ca['Total price for out-of-state students living on campus 2013-14'].fillna(int(df_Ca['Total price for out-of-state students living on campus 2013-14'].mean()), inplace=True)
df_Ca['Total  enrollment'].fillna(int(df_Ca['Total  enrollment'].mean()), inplace=True)
df_Ca['Full-time enrollment'].fillna(int(df_Ca['Full-time enrollment'].mean()), inplace=True)
df_Ca['Part-time enrollment'].fillna(int(df_Ca['Part-time enrollment'].mean()), inplace=True)
df_Ca['Undergraduate enrollment'].fillna(int(df_Ca['Undergraduate enrollment'].mean()), inplace=True)
df_Ca['Graduate enrollment'].fillna(int(df_Ca['Graduate enrollment'].mean()), inplace=True)
df_Ca['Full-time undergraduate enrollment'].fillna(int(df_Ca['Full-time undergraduate enrollment'].mean()), inplace=True)
df_Ca['Part-time undergraduate enrollment'].fillna(int(df_Ca['Part-time undergraduate enrollment'].mean()), inplace=True)
df_Ca['Percent of total enrollment that are American Indian or Alaska Native'].fillna(int(df_Ca['Percent of total enrollment that are American Indian or Alaska Native'].mean()), inplace=True)
df_Ca['Percent of total enrollment that are Asian'].fillna(int(df_Ca['Percent of total enrollment that are Asian'].mean()), inplace=True)
df_Ca['Percent of total enrollment that are Black or African American'].fillna(int(df_Ca['Percent of total enrollment that are Black or African American'].mean()), inplace=True)
df_Ca['Percent of total enrollment that are Hispanic/Latino'].fillna(int(df_Ca['Percent of total enrollment that are Hispanic/Latino'].mean()), inplace=True)
df_Ca['Percent of total enrollment that are Native Hawaiian or Other Pacific Islander'].fillna(int(df_Ca['Percent of total enrollment that are Native Hawaiian or Other Pacific Islander'].mean()), inplace=True)
df_Ca['Percent of total enrollment that are White'].fillna(int(df_Ca['Percent of total enrollment that are White'].mean()), inplace=True)
df_Ca['Percent of total enrollment that are two or more races'].fillna(int(df_Ca['Percent of total enrollment that are two or more races'].mean()), inplace=True)
df_Ca['Percent of total enrollment that are Nonresident Alien'].fillna(int(df_Ca['Percent of total enrollment that are Nonresident Alien'].mean()), inplace=True)
df_Ca['Percent of total enrollment that are Asian/Native Hawaiian/Pacific Islander'].fillna(int(df_Ca['Percent of total enrollment that are Asian/Native Hawaiian/Pacific Islander'].mean()), inplace=True)
df_Ca['Percent of total enrollment that are women'].fillna(int(df_Ca['Percent of total enrollment that are women'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are American Indian or Alaska Native'].fillna(int(df_Ca['Percent of undergraduate enrollment that are American Indian or Alaska Native'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are Asian'].fillna(int(df_Ca['Percent of undergraduate enrollment that are Asian'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are Black or African American'].fillna(int(df_Ca['Percent of undergraduate enrollment that are Black or African American'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are Hispanic/Latino'].fillna(int(df_Ca['Percent of undergraduate enrollment that are Hispanic/Latino'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are Native Hawaiian or Other Pacific Islander'].fillna(int(df_Ca['Percent of undergraduate enrollment that are Native Hawaiian or Other Pacific Islander'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are White'].fillna(int(df_Ca['Percent of undergraduate enrollment that are White'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are two or more races'].fillna(int(df_Ca['Percent of undergraduate enrollment that are two or more races'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are Race/ethnicity unknown'].fillna(int(df_Ca['Percent of undergraduate enrollment that are Race/ethnicity unknown'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are Nonresident Alien'].fillna(int(df_Ca['Percent of undergraduate enrollment that are Nonresident Alien'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are Asian/Native Hawaiian/Pacific Islander'].fillna(int(df_Ca['Percent of undergraduate enrollment that are Asian/Native Hawaiian/Pacific Islander'].mean()), inplace=True)
df_Ca['Percent of undergraduate enrollment that are women'].fillna(int(df_Ca['Percent of undergraduate enrollment that are women'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are American Indian or Alaska Native'].fillna(int(df_Ca['Percent of graduate enrollment that are American Indian or Alaska Native'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are Asian'].fillna(int(df_Ca['Percent of graduate enrollment that are Asian'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are Black or African American'].fillna(int(df_Ca['Percent of graduate enrollment that are Black or African American'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are Hispanic/Latino'].fillna(int(df_Ca['Percent of graduate enrollment that are Hispanic/Latino'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are Native Hawaiian or Other Pacific Islander'].fillna(int(df_Ca['Percent of graduate enrollment that are Native Hawaiian or Other Pacific Islander'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are White'].fillna(int(df_Ca['Percent of graduate enrollment that are White'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are two or more races'].fillna(int(df_Ca['Percent of graduate enrollment that are two or more races'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are Race/ethnicity unknown'].fillna(int(df_Ca['Percent of graduate enrollment that are Race/ethnicity unknown'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are Nonresident Alien'].fillna(int(df_Ca['Percent of graduate enrollment that are Nonresident Alien'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are Asian/Native Hawaiian/Pacific Islander'].fillna(int(df_Ca['Percent of graduate enrollment that are Asian/Native Hawaiian/Pacific Islander'].mean()), inplace=True)
df_Ca['Percent of graduate enrollment that are women'].fillna(int(df_Ca['Percent of graduate enrollment that are women'].mean()), inplace=True)
df_Ca['Number of first-time undergraduates - in-state'].fillna(int(df_Ca['Number of first-time undergraduates - in-state'].mean()), inplace=True)
df_Ca['Percent of first-time undergraduates - in-state'].fillna(int(df_Ca['Percent of first-time undergraduates - in-state'].mean()), inplace=True)
df_Ca['Number of first-time undergraduates - out-of-state'].fillna(int(df_Ca['Number of first-time undergraduates - out-of-state'].mean()), inplace=True)
df_Ca['Percent of first-time undergraduates - out-of-state'].fillna(int(df_Ca['Percent of first-time undergraduates - out-of-state'].mean()), inplace=True)
df_Ca['Number of first-time undergraduates - foreign countries'].fillna(int(df_Ca['Number of first-time undergraduates - foreign countries'].mean()), inplace=True)
df_Ca['Percent of first-time undergraduates - foreign countries'].fillna(int(df_Ca['Percent of first-time undergraduates - foreign countries'].mean()), inplace=True)
df_Ca['Number of first-time undergraduates - residence unknown'].fillna(int(df_Ca['Number of first-time undergraduates - residence unknown'].mean()), inplace=True)
df_Ca['Percent of first-time undergraduates - residence unknown'].fillna(int(df_Ca['Percent of first-time undergraduates - residence unknown'].mean()), inplace=True)
df_Ca['Graduation rate - Bachelor degree within 4 years, total'].fillna(int(df_Ca['Graduation rate - Bachelor degree within 4 years, total'].mean()), inplace=True)
df_Ca['Graduation rate - Bachelor degree within 5 years, total'].fillna(int(df_Ca['Graduation rate - Bachelor degree within 5 years, total'].mean()), inplace=True)
df_Ca['Graduation rate - Bachelor degree within 6 years, total'].fillna(int(df_Ca['Graduation rate - Bachelor degree within 6 years, total'].mean()), inplace=True)
df_Ca['Percent of freshmen receiving any financial aid'].fillna(int(df_Ca['Percent of freshmen receiving any financial aid'].mean()), inplace=True)
df_Ca['Percent of freshmen receiving federal, state, local or institutional grant aid'].fillna(int(df_Ca['Percent of freshmen receiving federal, state, local or institutional grant aid'].mean()), inplace=True)
df_Ca['Percent of freshmen  receiving federal grant aid'].fillna(int(df_Ca['Percent of freshmen  receiving federal grant aid'].mean()), inplace=True)
df_Ca['Percent of freshmen receiving Pell grants'].fillna(int(df_Ca['Percent of freshmen receiving Pell grants'].mean()), inplace=True)
df_Ca['Percent of freshmen receiving other federal grant aid'].fillna(int(df_Ca['Percent of freshmen receiving other federal grant aid'].mean()), inplace=True)
df_Ca['Percent of freshmen receiving state/local grant aid'].fillna(int(df_Ca['Percent of freshmen receiving state/local grant aid'].mean()), inplace=True)
df_Ca['Percent of freshmen receiving institutional grant aid'].fillna(int(df_Ca['Percent of freshmen receiving institutional grant aid'].mean()), inplace=True)
df_Ca['Percent of freshmen receiving student loan aid'].fillna(int(df_Ca['Percent of freshmen receiving student loan aid'].mean()), inplace=True)
df_Ca['Percent of freshmen receiving federal student loans'].fillna(int(df_Ca['Percent of freshmen receiving federal student loans'].mean()), inplace=True)
df_Ca['Percent of freshmen receiving other loan aid'].fillna(int(df_Ca['Percent of freshmen receiving other loan aid'].mean()), inplace=True)
df_Ca['Endowment assets (year end) per FTE enrollment (GASB)'].fillna(int(df_Ca['Endowment assets (year end) per FTE enrollment (GASB)'].mean()), inplace=True)
df_Ca['Endowment assets (year end) per FTE enrollment (FASB)'].fillna(int(df_Ca['Endowment assets (year end) per FTE enrollment (FASB)'].mean()), inplace=True)
df_Ca.info()
msno.bar(df_Ca)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Columns: 108 entries, Name to Endowment assets (year end) per FTE enrollment (FASB)
# dtypes: float64(97), object(11)
# memory usage: 1.3+ MB
# <Axes: >

# %%
dummies = pd.get_dummies(df_Hi[['Name', 'State abbreviation', 'FIPS state code', 'Geographic region', 'Sector of institution', 'Level of institution', 'Control of institution', 'Historically Black College or University', 'Degree of urbanization (Urban-centric locale)', 'Carnegie Classification 2010: Basic', 'Tribal college']], dtype=int) 
dummies.describe()
df_Hi= df_Hi.drop(['Name', 'State abbreviation', 'FIPS state code', 'Geographic region', 'Sector of institution', 'Level of institution', 'Control of institution', 'Historically Black College or University', 'Degree of urbanization (Urban-centric locale)', 'Carnegie Classification 2010: Basic', 'Tribal college'], axis = 1)
dummies.describe()
# Out:
#        Name_Abilene Christian University  Name_Adams State University  \
# count                        1534.000000                  1534.000000
# mean                            0.000652                     0.000652
# std                             0.025532                     0.025532
# min                             0.000000                     0.000000
# 25%                             0.000000                     0.000000
# 50%                             0.000000                     0.000000
# 75%                             0.000000                     0.000000
# max                             1.000000                     1.000000
#
#        Name_Adelphi University  Name_Adrian College  Name_Agnes Scott College  \
# count              1534.000000          1534.000000               1534.000000
# mean                  0.000652             0.000652                  0.000652
# std                   0.025532             0.025532                  0.025532
# ...

# %%
df_Hi = pd.concat([df_Hi, dummies], axis = 1)
df_Hi.describe()
#df_Hi= df_Hi.drop(['Name', 'State abbreviation', 'FIPS state code', 'Geographic region', 'Sector of institution', 'Level of institution', 'Control of institution'], axis = 1)
df_Hi.describe()

# %%
df_Hi.info()

# %%
df_Hi.head()

# %%
df_Hi.head()

# %%
# Assuming df_Ca is your DataFrame
numeric_columns = df_Hi.select_dtypes(include=['float64']).columns

# Calculate the correlation matrix
correlation_matrix = df_Hi[numeric_columns].corr()

# Get the top 10 most correlated pairs
top_correlations = correlation_matrix.unstack().sort_values(ascending=False).drop_duplicates().head(10)

# Extract the column names from the index
top_corr_columns = [pair[0] for pair in top_correlations.index]

# Create a DataFrame with the top correlated columns
top_corr_data = df_Ca[top_corr_columns]

# Create a pairplot
sns.pairplot(top_corr_data)
plt.show()

# %%
#SWEEEEEEEEE
